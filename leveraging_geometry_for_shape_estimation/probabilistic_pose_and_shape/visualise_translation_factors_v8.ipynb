# %%
import cv2
from cv2 import threshold
import numpy as np
import sys
import os
import json
from torchvision import models
from tqdm import tqdm
from pytorch3d.renderer import look_at_view_transform
from math import ceil
import torch
from pytorch3d.io import load_obj, load_ply
from scipy.spatial.transform import Rotation as scipy_rot
from matplotlib import pyplot as plt
from probabilistic_formulation.tests.test_factors_lines import create_k3d_plot
import copy
import ipyplot

# %load_ext autoreload
# %autoreload 2

from leveraging_geometry_for_shape_estimation.keypoint_matching.get_matches_3d import load_information_depth_camera,create_pixel_bearing,pb_and_depth_to_wc
from leveraging_geometry_for_shape_estimation.probabilistic_pose_and_shape.pose import init_Rs,init_Ts,get_pb_real_grid,get_R_limits,get_T_limits, create_pose_info_dict, check_gt_pose_in_limits, get_nearest_pose_to_gt
from leveraging_geometry_for_shape_estimation.probabilistic_pose_and_shape.ground_plane import get_model_to_infos,sample_Ts_ground_plane,filter_Ts
from leveraging_geometry_for_shape_estimation.probabilistic_pose_and_shape.translation_from_lines_v8 import *
from leveraging_geometry_for_shape_estimation.probabilistic_pose_and_shape.visualise_T_factors import plot_lines_T_correct_visualisation, get_pointsize_from_Ts
from leveraging_geometry_for_shape_estimation.probabilistic_pose_and_shape.translation_from_lines_visualise_v1 import visualise_single_example
from leveraging_geometry_for_shape_estimation.segmentation.meshrcnn_vis_tools import draw_boxes
from leveraging_geometry_for_shape_estimation.utilities.write_on_images import draw_lines
from leveraging_geometry_for_shape_estimation.data_conversion.create_dirs import dict_replace_value

from probabilistic_formulation.utilities import create_all_possible_combinations,get_uvuv_p_from_superpoint,create_all_possible_combinations_uvuv_p_together
from probabilistic_formulation.factors.factors_T.factors_lines_multiple_T import get_factor_reproject_lines_multiple_T, get_factor_reproject_lines_multiple_T_threshold, get_factor_reproject_lines_multiple_T_with_Scale
from probabilistic_formulation.factors.factors_T.bbox import get_factor_bbox_multiple_T
from probabilistic_formulation.tests.test_reproject_lines import load_lines_2D,load_lines_3D,get_cuboid_line_dirs_3D,plot_lines_T,plot_bbox, plot_points_T
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
# exp_path = '/scratches/octopus_2/fml35/experiments/leveraging_geometry_for_shape/exp_208_debug_bbox'
# exp_path = '/scratches/octopus_2/fml35/experiments/leveraging_geometry_for_shape/exp_219_debug'
exp_path = '/scratches/octopus_2/fml35/experiments/leveraging_geometry_for_shape/debug/points'

global_info = exp_path + '/global_information.json'
with open(global_info,'r') as f:
    global_config = json.load(f)


# global_config["pose_and_shape_probabilistic"]["reproject_lines"]["signal"] = "lines_classifier"
# global_config["general"]["use_existing"] = []



# global_config["pose_and_shape_probabilistic"]["reproject_lines"]["network_path"] = "/scratch2/fml35/experiments/classify_T_from_lines_02/date_2022_03_30_time_17_52_49_bbox_augmentation_ADAM/saved_models/last_epoch.pth"
# global_config["pose_and_shape_probabilistic"]["reproject_lines"]["network_path"] = "/scratch2/fml35/experiments/classify_T_from_lines_02/date_2022_04_06_time_16_36_29_black_lines_bbox_no_gt_z_hard_data_lr_halve/saved_models/last_epoch.pth"
# global_config["pose_and_shape_probabilistic"]["reproject_lines"]["classifier_exp_path"] = "/scratch2/fml35/experiments/classify_T_from_lines_02/date_2022_04_06_time_16_36_29_black_lines_bbox_no_gt_z_hard_data_lr_halve"
# global_config["pose_and_shape_probabilistic"]["reproject_lines"]["classifier_epoch"]= 'last'
# global_config["hierachial_grid_search"]["number_stages"] =  3
# global_config["hierachial_grid_search"]["stages"] =  [{"which":"T","info_T":{"center":"gt","range":1,"range_type": "absolute","steps_per_dim":10}},
#                         {"which":"S","info_S":{"center":"mode","range":"full","range_type": "absolute","steps_per_dim":10}},
#                         {"which":"S_T","info_S":{"center":"max","range":0.3,"range_type": "relative","steps_per_dim":3},"info_T":{"center":"max","range":0.3,"range_type": "absolute","steps_per_dim":3}}
# ]

global_config["general"]["gpu"] = 0

# %%
global_config = dict_replace_value(global_config,'/scratch/fml35/','/scratches/octopus/fml35/')
global_config = dict_replace_value(global_config,'/scratch2/fml35/','/scratches/octopus_2/fml35/')

target_folder = global_config["general"]["target_folder"]
model_to_infos = get_model_to_infos()

# scene0011_01-000400_00_000_03_chair
# name = 'scene0011_01-000400_00_000_03.json'
# name = 'scene0011_00-001200_01_000_02.json'
# name = 'scene0025_00-001400_00_000_01.json'
# name = 'scene0430_00-000400_01_000_00.json'
# name = 'scene0598_01-000400_00_000_00.json'
# name = 'scene0011_00-001900_03_000_00.json'
# name = 'scene0011_01-000200_00_000_00.json' # bug with mapping ?? no all correct
# name = 'scene0011_00-000000_00_000_00.json'
# name = 'scene0011_00-001200_01_000_00.json'
# name = 'scene0011_00-002100_03_000_00.json'
# name = 'scene0665_01-000400_02_000_00.json'

# %%
cfg_1 = copy.deepcopy(global_config)
cfg_2 = copy.deepcopy(global_config)
cfg_2["pose_and_shape_probabilistic"]["reproject_lines"]["signal"] = "lines"

# %%
gt_T = [0.5446935880177487, -0.2386588813253322, 1.9058292932368883]

# %%
configs = [cfg_1]
# line_indices_2ds = [None,[1,4,24]]
line_indices_2ds = [None,None]
line_indices_3ds = [None,None]
use_gt_retrievals = [False,False]
use_gt_Rs = [False,False]
# specific_Ts = [[[ 0.1045, -0.0162,  1.4871]],None]
# specific_Ts = [[[-0.1486571784928421, 0.010539434249897894, 1.5424885361165246],[-0.3,0.0,3.0]],None]
# specific_Ts = [[[-0.3,0.0,3.0]],None]
# specific_Ts = [[gt_T + np.array([0,0,0.1*i]) for i in range(4,5)]]
specific_Ts = [None]
print(specific_Ts)
# names = ['scene0046_02-000500_00_000_02.json','scene0030_00-001300_00_000_00.json']
# names = ['scene0300_00-000500_00_000_00.json']

names = ['scene0011_00-000000_00_000_00.json']
# Out:
# [None]

# %%
classifier_config = load_json(global_config["pose_and_shape_probabilistic"]["reproject_lines"]["classifier_exp_path"] + '/code/leveraging_geometry_for_shape_estimation/probabilistic_pose_and_shape/train_pose_classifier_from_lines/config.json')
classifier_config = dict_replace_value(classifier_config,'/scratch2/fml35/','/scratches/octopus_2/fml35/')
if global_config["general"]["run_on_octopus"] == 'False':
        classifier_config = dict_replace_value(classifier_config,'/scratch/fml35/','/scratches/octopus/fml35/')
        classifier_config = dict_replace_value(classifier_config,'/scratch2/fml35/','/scratches/octopus_2/fml35/')
network = load_classifier(cfg_1,classifier_config)
scale_range = load_json(determine_base_dir(global_config,'segmentation') + '/scaling_limits.json')
# Out:
# loading network
# loaded network
# cuda:0

# %%
outputs=[]
img_names = ['selected_T_selected_S','closest_T_closest_S','closest_T_selected_S','selected_T_closest_S']
# pose_information,imgs,Ts,factors,area_accepted_all_Ts
for i in range(len(configs)):
        for j in range(configs[i]['hierachial_grid_search']['number_stages']):
            if j == 0:
                pose_information = None
            pose_information,_,factor_output = get_pose_single_example(configs[i],names[i],model_to_infos,pose_information,scale_range,j,line_indices_2d=line_indices_2ds[i],line_indices_3d=line_indices_3ds[i],use_gt_retrieval=use_gt_retrievals[i],use_gt_R=use_gt_Rs[i],specific_Ts=specific_Ts[i],network=network,classifier_config=classifier_config)
            
            # eval_results = eval_factors(factor_output,np.array(pose_information["gt_T"]))
            # print(eval_results)
            imgs,img_annotations = visualise_single_example(global_config,names[i].replace('.json','_{}.json'.format(str(j).zfill(2))),factor_output,img_names,model_to_infos,classifier_config)
            # imgs,img_annotations = None,None
            eval_results = None
            output = (pose_information,factor_output,imgs,img_annotations,eval_results)
            outputs.append(output)
# Out:
# /scratch/fml35/environments/shape_env_octo/lib/python3.6/site-packages/torch/functional.py:445: UserWarning: torch.meshgrid: in an upcoming release, it will be required to pass the indexing argument. (Triggered internally at  ../aten/src/ATen/native/TensorShape.cpp:2157.)
#   return _VF.meshgrid(tensors, **kwargs)  # type: ignore[attr-defined]
# /home/mifs/fml35/code/shape/leveraging_geometry_for_shape_estimation/probabilistic_pose_and_shape/translation_from_lines_v8.py:283: UserWarning: __floordiv__ is deprecated, and its behavior will change in a future version of pytorch. It currently rounds toward 0 (like the 'trunc' function NOT 'floor'). This results in incorrect rounding for negative values. To keep the current behavior, use torch.div(a, b, rounding_mode='trunc'), or for actual floor division, use torch.div(a, b, rounding_mode='floor').
#   best_T_index = (best_index_overall // Ss.shape[0]).item()
# (20960, 3)
# (20960, 3)
# (20960, 3)
# (20960, 3)

# %%
# ipyplot.plot_images([outputs[0][1][0],outputs[1][1][0]], max_images=20, img_width=600)
ipyplot.plot_images([output[2][0] for output in outputs], max_images=20, img_width=700)
# ipyplot.plot_images([imgs[0][i] for i in range(20)], max_images=20, img_width=120)
print(len(outputs))
# Out:
#     <style>
#         #ipyplot-html-viewer-toggle-78uwvB7wUHsoFyVJUjW2jp {
#             position: absolute;
#             top: -9999px;
#             left: -9999px;
#             visibility: hidden;
#         }
#
#         #ipyplot-html-viewer-label-78uwvB7wUHsoFyVJUjW2jp {
#             position: relative;
#             display: inline-block;
#             cursor: pointer;
#             color: blue;
#             text-decoration: underline;
#         }
#
#         #ipyplot-html-viewer-textarea-78uwvB7wUHsoFyVJUjW2jp {
#             background: lightgrey;
#             width: 100%;
#             height: 0px;
#             display: none;
#         }
#
#         #ipyplot-html-viewer-toggle-78uwvB7wUHsoFyVJUjW2jp:checked ~ #ipyplot-html-viewer-textarea-78uwvB7wUHsoFyVJUjW2jp {
#             height: 200px;
#             display: block;
#         }
#
#         #ipyplot-html-viewer-toggle-78uwvB7wUHsoFyVJUjW2jp:checked + #ipyplot-html-viewer-label-78uwvB7wUHsoFyVJUjW2jp:after {
#             content: "hide html";
#             position: absolute;
#             top: 0;
#             left: 0;
#             right: 0;
#             bottom: 0;
#             background: white;
#             cursor: pointer;
#             color: blue;
#             text-decoration: underline;
#         }
#     </style>
#     <div>
#         <input type="checkbox" id="ipyplot-html-viewer-toggle-78uwvB7wUHsoFyVJUjW2jp">
#         <label id="ipyplot-html-viewer-label-78uwvB7wUHsoFyVJUjW2jp" for="ipyplot-html-viewer-toggle-78uwvB7wUHsoFyVJUjW2jp">show html</label>
#         <textarea id="ipyplot-html-viewer-textarea-78uwvB7wUHsoFyVJUjW2jp" readonly>
#
#         <style>
#         #ipyplot-imgs-container-div-mtP76DGLTDZfLubjjrGr8k {
#             width: 100%;
#             height: 100%;
#             margin: 0%;
#             overflow: auto;
#             position: relative;
#             overflow-y: scroll;
#         }
#
#         div.ipyplot-placeholder-div-mtP76DGLTDZfLubjjrGr8k {
#             width: 700px;
#             display: inline-block;
#             margin: 3px;
#             position: relative;
#         }
#
#         div.ipyplot-content-div-mtP76DGLTDZfLubjjrGr8k {
#             width: 700px;
#             background: white;
#             display: inline-block;
#             vertical-align: top;
#             text-align: center;
#             position: relative;
#             border: 2px solid #ddd;
#             top: 0;
#             left: 0;
#         }
#
#         div.ipyplot-content-div-mtP76DGLTDZfLubjjrGr8k span.ipyplot-img-close {
#             display: none;
#         }
#
#         div.ipyplot-content-div-mtP76DGLTDZfLubjjrGr8k span {
#             width: 100%;
#             height: 100%;
#             position: absolute;
#             top: 0;
#             left: 0;
#         }
#
#         div.ipyplot-content-div-mtP76DGLTDZfLubjjrGr8k img {
#             width: 700px;
#         }
#
#         div.ipyplot-content-div-mtP76DGLTDZfLubjjrGr8k span.ipyplot-img-close:hover {
#             cursor: zoom-out;
#         }
#         div.ipyplot-content-div-mtP76DGLTDZfLubjjrGr8k span.ipyplot-img-expand:hover {
#             cursor: zoom-in;
#         }
#
#         div[id^=ipyplot-content-div-mtP76DGLTDZfLubjjrGr8k]:target {
#             transform: scale(2.5);
#             transform-origin: left top;
#             z-index: 5000;
#             top: 0;
#             left: 0;
#             position: absolute;
#         }
#
#         div[id^=ipyplot-content-div-mtP76DGLTDZfLubjjrGr8k]:target span.ipyplot-img-close {
#             display: block;
#         }
#
#         div[id^=ipyplot-content-div-mtP76DGLTDZfLubjjrGr8k]:target span.ipyplot-img-expand {
#             display: none;
#         }
#         </style>
#     <div id="ipyplot-imgs-container-div-mtP76DGLTDZfLubjjrGr8k">
#     <div class="ipyplot-placeholder-div-mtP76DGLTDZfLubjjrGr8k">
#         <div id="ipyplot-content-div-mtP76DGLTDZfLubjjrGr8k-iwtMoRDTQdRJuSYrQUtzDL" class="ipyplot-content-div-mtP76DGLTDZfLubjjrGr8k">
#             <h4 style="font-size: 12px; word-wrap: break-word;">0</h4>
#             <img src="data:image/png;base64,..."/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-mtP76DGLTDZfLubjjrGr8k-iwtMoRDTQdRJuSYrQUtzDL">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#     </div>
#         </textarea>
#     </div>
#         <style>
#         #ipyplot-imgs-container-div-mtP76DGLTDZfLubjjrGr8k {
#             width: 100%;
#             height: 100%;
#             margin: 0%;
#             overflow: auto;
#             position: relative;
#             overflow-y: scroll;
#         }
#
#         div.ipyplot-placeholder-div-mtP76DGLTDZfLubjjrGr8k {
#             width: 700px;
#             display: inline-block;
#             margin: 3px;
#             position: relative;
#         }
#
#         div.ipyplot-content-div-mtP76DGLTDZfLubjjrGr8k {
#             width: 700px;
#             background: white;
#             display: inline-block;
#             vertical-align: top;
#             text-align: center;
#             position: relative;
#             border: 2px solid #ddd;
#             top: 0;
#             left: 0;
#         }
#
#         div.ipyplot-content-div-mtP76DGLTDZfLubjjrGr8k span.ipyplot-img-close {
#             display: none;
#         }
#
#         div.ipyplot-content-div-mtP76DGLTDZfLubjjrGr8k span {
#             width: 100%;
#             height: 100%;
#             position: absolute;
#             top: 0;
#             left: 0;
#         }
#
#         div.ipyplot-content-div-mtP76DGLTDZfLubjjrGr8k img {
#             width: 700px;
#         }
#
#         div.ipyplot-content-div-mtP76DGLTDZfLubjjrGr8k span.ipyplot-img-close:hover {
#             cursor: zoom-out;
#         }
#         div.ipyplot-content-div-mtP76DGLTDZfLubjjrGr8k span.ipyplot-img-expand:hover {
#             cursor: zoom-in;
#         }
#
#         div[id^=ipyplot-content-div-mtP76DGLTDZfLubjjrGr8k]:target {
#             transform: scale(2.5);
#             transform-origin: left top;
#             z-index: 5000;
#             top: 0;
#             left: 0;
#             position: absolute;
#         }
#
#         div[id^=ipyplot-content-div-mtP76DGLTDZfLubjjrGr8k]:target span.ipyplot-img-close {
#             display: block;
#         }
#
#         div[id^=ipyplot-content-div-mtP76DGLTDZfLubjjrGr8k]:target span.ipyplot-img-expand {
#             display: none;
#         }
#         </style>
#     <div id="ipyplot-imgs-container-div-mtP76DGLTDZfLubjjrGr8k">
#     <div class="ipyplot-placeholder-div-mtP76DGLTDZfLubjjrGr8k">
#         <div id="ipyplot-content-div-mtP76DGLTDZfLubjjrGr8k-iwtMoRDTQdRJuSYrQUtzDL" class="ipyplot-content-div-mtP76DGLTDZfLubjjrGr8k">
#             <h4 style="font-size: 12px; word-wrap: break-word;">0</h4>
#             <img src="data:image/png;base64,..."/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-mtP76DGLTDZfLubjjrGr8k-iwtMoRDTQdRJuSYrQUtzDL">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#     </div>
# 1

# %%
# all_2d_to_all_3d = outputs[0][1]["all_factors_T_2d_3d_selected_T"]

# %%
# CLOSEST TO GT TS
for k in range(1,4):
    print(img_names[k])
    ipyplot.plot_images([output[2][k] for output in outputs], max_images=20, img_width=700)
# Out:
# closest_T_closest_S
#     <style>
#         #ipyplot-html-viewer-toggle-erna2M7UUGd6GbPybQhm2v {
#             position: absolute;
#             top: -9999px;
#             left: -9999px;
#             visibility: hidden;
#         }
#
#         #ipyplot-html-viewer-label-erna2M7UUGd6GbPybQhm2v {
#             position: relative;
#             display: inline-block;
#             cursor: pointer;
#             color: blue;
#             text-decoration: underline;
#         }
#
#         #ipyplot-html-viewer-textarea-erna2M7UUGd6GbPybQhm2v {
#             background: lightgrey;
#             width: 100%;
#             height: 0px;
#             display: none;
#         }
#
#         #ipyplot-html-viewer-toggle-erna2M7UUGd6GbPybQhm2v:checked ~ #ipyplot-html-viewer-textarea-erna2M7UUGd6GbPybQhm2v {
#             height: 200px;
#             display: block;
#         }
#
#         #ipyplot-html-viewer-toggle-erna2M7UUGd6GbPybQhm2v:checked + #ipyplot-html-viewer-label-erna2M7UUGd6GbPybQhm2v:after {
#             content: "hide html";
#             position: absolute;
#             top: 0;
#             left: 0;
#             right: 0;
#             bottom: 0;
#             background: white;
#             cursor: pointer;
#             color: blue;
#             text-decoration: underline;
#         }
#     </style>
#     <div>
#         <input type="checkbox" id="ipyplot-html-viewer-toggle-erna2M7UUGd6GbPybQhm2v">
#         <label id="ipyplot-html-viewer-label-erna2M7UUGd6GbPybQhm2v" for="ipyplot-html-viewer-toggle-erna2M7UUGd6GbPybQhm2v">show html</label>
#         <textarea id="ipyplot-html-viewer-textarea-erna2M7UUGd6GbPybQhm2v" readonly>
#
#         <style>
#         #ipyplot-imgs-container-div-WkHjzB7urfme7bM2rXvgUJ {
#             width: 100%;
#             height: 100%;
#             margin: 0%;
#             overflow: auto;
#             position: relative;
#             overflow-y: scroll;
#         }
#
#         div.ipyplot-placeholder-div-WkHjzB7urfme7bM2rXvgUJ {
#             width: 700px;
#             display: inline-block;
#             margin: 3px;
#             position: relative;
#         }
#
#         div.ipyplot-content-div-WkHjzB7urfme7bM2rXvgUJ {
#             width: 700px;
#             background: white;
#             display: inline-block;
#             vertical-align: top;
#             text-align: center;
#             position: relative;
#             border: 2px solid #ddd;
#             top: 0;
#             left: 0;
#         }
#
#         div.ipyplot-content-div-WkHjzB7urfme7bM2rXvgUJ span.ipyplot-img-close {
#             display: none;
#         }
#
#         div.ipyplot-content-div-WkHjzB7urfme7bM2rXvgUJ span {
#             width: 100%;
#             height: 100%;
#             position: absolute;
#             top: 0;
#             left: 0;
#         }
#
#         div.ipyplot-content-div-WkHjzB7urfme7bM2rXvgUJ img {
#             width: 700px;
#         }
#
#         div.ipyplot-content-div-WkHjzB7urfme7bM2rXvgUJ span.ipyplot-img-close:hover {
#             cursor: zoom-out;
#         }
#         div.ipyplot-content-div-WkHjzB7urfme7bM2rXvgUJ span.ipyplot-img-expand:hover {
#             cursor: zoom-in;
#         }
#
#         div[id^=ipyplot-content-div-WkHjzB7urfme7bM2rXvgUJ]:target {
#             transform: scale(2.5);
#             transform-origin: left top;
#             z-index: 5000;
#             top: 0;
#             left: 0;
#             position: absolute;
#         }
#
#         div[id^=ipyplot-content-div-WkHjzB7urfme7bM2rXvgUJ]:target span.ipyplot-img-close {
#             display: block;
#         }
#
#         div[id^=ipyplot-content-div-WkHjzB7urfme7bM2rXvgUJ]:target span.ipyplot-img-expand {
#             display: none;
#         }
#         </style>
#     <div id="ipyplot-imgs-container-div-WkHjzB7urfme7bM2rXvgUJ">
#     <div class="ipyplot-placeholder-div-WkHjzB7urfme7bM2rXvgUJ">
#         <div id="ipyplot-content-div-WkHjzB7urfme7bM2rXvgUJ-KyAMDAQNcEeq5V7J93U9ht" class="ipyplot-content-div-WkHjzB7urfme7bM2rXvgUJ">
#             <h4 style="font-size: 12px; word-wrap: break-word;">0</h4>
#             <img src="data:image/png;base64,..."/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-WkHjzB7urfme7bM2rXvgUJ-KyAMDAQNcEeq5V7J93U9ht">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#     </div>
#         </textarea>
#     </div>
#         <style>
#         #ipyplot-imgs-container-div-WkHjzB7urfme7bM2rXvgUJ {
#             width: 100%;
#             height: 100%;
#             margin: 0%;
#             overflow: auto;
#             position: relative;
#             overflow-y: scroll;
#         }
#
#         div.ipyplot-placeholder-div-WkHjzB7urfme7bM2rXvgUJ {
#             width: 700px;
#             display: inline-block;
#             margin: 3px;
#             position: relative;
#         }
#
#         div.ipyplot-content-div-WkHjzB7urfme7bM2rXvgUJ {
#             width: 700px;
#             background: white;
#             display: inline-block;
#             vertical-align: top;
#             text-align: center;
#             position: relative;
#             border: 2px solid #ddd;
#             top: 0;
#             left: 0;
#         }
#
#         div.ipyplot-content-div-WkHjzB7urfme7bM2rXvgUJ span.ipyplot-img-close {
#             display: none;
#         }
#
#         div.ipyplot-content-div-WkHjzB7urfme7bM2rXvgUJ span {
#             width: 100%;
#             height: 100%;
#             position: absolute;
#             top: 0;
#             left: 0;
#         }
#
#         div.ipyplot-content-div-WkHjzB7urfme7bM2rXvgUJ img {
#             width: 700px;
#         }
#
#         div.ipyplot-content-div-WkHjzB7urfme7bM2rXvgUJ span.ipyplot-img-close:hover {
#             cursor: zoom-out;
#         }
#         div.ipyplot-content-div-WkHjzB7urfme7bM2rXvgUJ span.ipyplot-img-expand:hover {
#             cursor: zoom-in;
#         }
#
#         div[id^=ipyplot-content-div-WkHjzB7urfme7bM2rXvgUJ]:target {
#             transform: scale(2.5);
#             transform-origin: left top;
#             z-index: 5000;
#             top: 0;
#             left: 0;
#             position: absolute;
#         }
#
#         div[id^=ipyplot-content-div-WkHjzB7urfme7bM2rXvgUJ]:target span.ipyplot-img-close {
#             display: block;
#         }
#
#         div[id^=ipyplot-content-div-WkHjzB7urfme7bM2rXvgUJ]:target span.ipyplot-img-expand {
#             display: none;
#         }
#         </style>
#     <div id="ipyplot-imgs-container-div-WkHjzB7urfme7bM2rXvgUJ">
#     <div class="ipyplot-placeholder-div-WkHjzB7urfme7bM2rXvgUJ">
#         <div id="ipyplot-content-div-WkHjzB7urfme7bM2rXvgUJ-KyAMDAQNcEeq5V7J93U9ht" class="ipyplot-content-div-WkHjzB7urfme7bM2rXvgUJ">
#             <h4 style="font-size: 12px; word-wrap: break-word;">0</h4>
#             <img src="data:image/png;base64,..."/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-WkHjzB7urfme7bM2rXvgUJ-KyAMDAQNcEeq5V7J93U9ht">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#     </div>
# closest_T_selected_S
#     <style>
#         #ipyplot-html-viewer-toggle-gQj3CLztf6xFFYz4GtwHBz {
#             position: absolute;
#             top: -9999px;
#             left: -9999px;
#             visibility: hidden;
#         }
#
#         #ipyplot-html-viewer-label-gQj3CLztf6xFFYz4GtwHBz {
#             position: relative;
#             display: inline-block;
#             cursor: pointer;
#             color: blue;
#             text-decoration: underline;
#         }
#
#         #ipyplot-html-viewer-textarea-gQj3CLztf6xFFYz4GtwHBz {
#             background: lightgrey;
#             width: 100%;
#             height: 0px;
#             display: none;
#         }
#
#         #ipyplot-html-viewer-toggle-gQj3CLztf6xFFYz4GtwHBz:checked ~ #ipyplot-html-viewer-textarea-gQj3CLztf6xFFYz4GtwHBz {
#             height: 200px;
#             display: block;
#         }
#
#         #ipyplot-html-viewer-toggle-gQj3CLztf6xFFYz4GtwHBz:checked + #ipyplot-html-viewer-label-gQj3CLztf6xFFYz4GtwHBz:after {
#             content: "hide html";
#             position: absolute;
#             top: 0;
#             left: 0;
#             right: 0;
#             bottom: 0;
#             background: white;
#             cursor: pointer;
#             color: blue;
#             text-decoration: underline;
#         }
#     </style>
#     <div>
#         <input type="checkbox" id="ipyplot-html-viewer-toggle-gQj3CLztf6xFFYz4GtwHBz">
#         <label id="ipyplot-html-viewer-label-gQj3CLztf6xFFYz4GtwHBz" for="ipyplot-html-viewer-toggle-gQj3CLztf6xFFYz4GtwHBz">show html</label>
#         <textarea id="ipyplot-html-viewer-textarea-gQj3CLztf6xFFYz4GtwHBz" readonly>
#
#         <style>
#         #ipyplot-imgs-container-div-USHDkCD3Yc6QCTcHHG8hFf {
#             width: 100%;
#             height: 100%;
#             margin: 0%;
#             overflow: auto;
#             position: relative;
#             overflow-y: scroll;
#         }
#
#         div.ipyplot-placeholder-div-USHDkCD3Yc6QCTcHHG8hFf {
#             width: 700px;
#             display: inline-block;
#             margin: 3px;
#             position: relative;
#         }
#
#         div.ipyplot-content-div-USHDkCD3Yc6QCTcHHG8hFf {
#             width: 700px;
#             background: white;
#             display: inline-block;
#             vertical-align: top;
#             text-align: center;
#             position: relative;
#             border: 2px solid #ddd;
#             top: 0;
#             left: 0;
#         }
#
#         div.ipyplot-content-div-USHDkCD3Yc6QCTcHHG8hFf span.ipyplot-img-close {
#             display: none;
#         }
#
#         div.ipyplot-content-div-USHDkCD3Yc6QCTcHHG8hFf span {
#             width: 100%;
#             height: 100%;
#             position: absolute;
#             top: 0;
#             left: 0;
#         }
#
#         div.ipyplot-content-div-USHDkCD3Yc6QCTcHHG8hFf img {
#             width: 700px;
#         }
#
#         div.ipyplot-content-div-USHDkCD3Yc6QCTcHHG8hFf span.ipyplot-img-close:hover {
#             cursor: zoom-out;
#         }
#         div.ipyplot-content-div-USHDkCD3Yc6QCTcHHG8hFf span.ipyplot-img-expand:hover {
#             cursor: zoom-in;
#         }
#
#         div[id^=ipyplot-content-div-USHDkCD3Yc6QCTcHHG8hFf]:target {
#             transform: scale(2.5);
#             transform-origin: left top;
#             z-index: 5000;
#             top: 0;
#             left: 0;
#             position: absolute;
#         }
#
#         div[id^=ipyplot-content-div-USHDkCD3Yc6QCTcHHG8hFf]:target span.ipyplot-img-close {
#             display: block;
#         }
#
#         div[id^=ipyplot-content-div-USHDkCD3Yc6QCTcHHG8hFf]:target span.ipyplot-img-expand {
#             display: none;
#         }
#         </style>
#     <div id="ipyplot-imgs-container-div-USHDkCD3Yc6QCTcHHG8hFf">
#     <div class="ipyplot-placeholder-div-USHDkCD3Yc6QCTcHHG8hFf">
#         <div id="ipyplot-content-div-USHDkCD3Yc6QCTcHHG8hFf-aKedRFxNgNjXyimSGdjtjw" class="ipyplot-content-div-USHDkCD3Yc6QCTcHHG8hFf">
#             <h4 style="font-size: 12px; word-wrap: break-word;">0</h4>
#             <img src="data:image/png;base64,..."/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-USHDkCD3Yc6QCTcHHG8hFf-aKedRFxNgNjXyimSGdjtjw">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#     </div>
#         </textarea>
#     </div>
#         <style>
#         #ipyplot-imgs-container-div-USHDkCD3Yc6QCTcHHG8hFf {
#             width: 100%;
#             height: 100%;
#             margin: 0%;
#             overflow: auto;
#             position: relative;
#             overflow-y: scroll;
#         }
#
#         div.ipyplot-placeholder-div-USHDkCD3Yc6QCTcHHG8hFf {
#             width: 700px;
#             display: inline-block;
#             margin: 3px;
#             position: relative;
#         }
#
#         div.ipyplot-content-div-USHDkCD3Yc6QCTcHHG8hFf {
#             width: 700px;
#             background: white;
#             display: inline-block;
#             vertical-align: top;
#             text-align: center;
#             position: relative;
#             border: 2px solid #ddd;
#             top: 0;
#             left: 0;
#         }
#
#         div.ipyplot-content-div-USHDkCD3Yc6QCTcHHG8hFf span.ipyplot-img-close {
#             display: none;
#         }
#
#         div.ipyplot-content-div-USHDkCD3Yc6QCTcHHG8hFf span {
#             width: 100%;
#             height: 100%;
#             position: absolute;
#             top: 0;
#             left: 0;
#         }
#
#         div.ipyplot-content-div-USHDkCD3Yc6QCTcHHG8hFf img {
#             width: 700px;
#         }
#
#         div.ipyplot-content-div-USHDkCD3Yc6QCTcHHG8hFf span.ipyplot-img-close:hover {
#             cursor: zoom-out;
#         }
#         div.ipyplot-content-div-USHDkCD3Yc6QCTcHHG8hFf span.ipyplot-img-expand:hover {
#             cursor: zoom-in;
#         }
#
#         div[id^=ipyplot-content-div-USHDkCD3Yc6QCTcHHG8hFf]:target {
#             transform: scale(2.5);
#             transform-origin: left top;
#             z-index: 5000;
#             top: 0;
#             left: 0;
#             position: absolute;
#         }
#
#         div[id^=ipyplot-content-div-USHDkCD3Yc6QCTcHHG8hFf]:target span.ipyplot-img-close {
#             display: block;
#         }
#
#         div[id^=ipyplot-content-div-USHDkCD3Yc6QCTcHHG8hFf]:target span.ipyplot-img-expand {
#             display: none;
#         }
#         </style>
#     <div id="ipyplot-imgs-container-div-USHDkCD3Yc6QCTcHHG8hFf">
#     <div class="ipyplot-placeholder-div-USHDkCD3Yc6QCTcHHG8hFf">
#         <div id="ipyplot-content-div-USHDkCD3Yc6QCTcHHG8hFf-aKedRFxNgNjXyimSGdjtjw" class="ipyplot-content-div-USHDkCD3Yc6QCTcHHG8hFf">
#             <h4 style="font-size: 12px; word-wrap: break-word;">0</h4>
#             <img src="data:image/png;base64,..."/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-USHDkCD3Yc6QCTcHHG8hFf-aKedRFxNgNjXyimSGdjtjw">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#     </div>
# selected_T_closest_S
#     <style>
#         #ipyplot-html-viewer-toggle-oNhqEYNAJEki3Z6EwGUC5Y {
#             position: absolute;
#             top: -9999px;
#             left: -9999px;
#             visibility: hidden;
#         }
#
#         #ipyplot-html-viewer-label-oNhqEYNAJEki3Z6EwGUC5Y {
#             position: relative;
#             display: inline-block;
#             cursor: pointer;
#             color: blue;
#             text-decoration: underline;
#         }
#
#         #ipyplot-html-viewer-textarea-oNhqEYNAJEki3Z6EwGUC5Y {
#             background: lightgrey;
#             width: 100%;
#             height: 0px;
#             display: none;
#         }
#
#         #ipyplot-html-viewer-toggle-oNhqEYNAJEki3Z6EwGUC5Y:checked ~ #ipyplot-html-viewer-textarea-oNhqEYNAJEki3Z6EwGUC5Y {
#             height: 200px;
#             display: block;
#         }
#
#         #ipyplot-html-viewer-toggle-oNhqEYNAJEki3Z6EwGUC5Y:checked + #ipyplot-html-viewer-label-oNhqEYNAJEki3Z6EwGUC5Y:after {
#             content: "hide html";
#             position: absolute;
#             top: 0;
#             left: 0;
#             right: 0;
#             bottom: 0;
#             background: white;
#             cursor: pointer;
#             color: blue;
#             text-decoration: underline;
#         }
#     </style>
#     <div>
#         <input type="checkbox" id="ipyplot-html-viewer-toggle-oNhqEYNAJEki3Z6EwGUC5Y">
#         <label id="ipyplot-html-viewer-label-oNhqEYNAJEki3Z6EwGUC5Y" for="ipyplot-html-viewer-toggle-oNhqEYNAJEki3Z6EwGUC5Y">show html</label>
#         <textarea id="ipyplot-html-viewer-textarea-oNhqEYNAJEki3Z6EwGUC5Y" readonly>
#
#         <style>
#         #ipyplot-imgs-container-div-NCwoyGmj874S2tcQhNTbKb {
#             width: 100%;
#             height: 100%;
#             margin: 0%;
#             overflow: auto;
#             position: relative;
#             overflow-y: scroll;
#         }
#
#         div.ipyplot-placeholder-div-NCwoyGmj874S2tcQhNTbKb {
#             width: 700px;
#             display: inline-block;
#             margin: 3px;
#             position: relative;
#         }
#
#         div.ipyplot-content-div-NCwoyGmj874S2tcQhNTbKb {
#             width: 700px;
#             background: white;
#             display: inline-block;
#             vertical-align: top;
#             text-align: center;
#             position: relative;
#             border: 2px solid #ddd;
#             top: 0;
#             left: 0;
#         }
#
#         div.ipyplot-content-div-NCwoyGmj874S2tcQhNTbKb span.ipyplot-img-close {
#             display: none;
#         }
#
#         div.ipyplot-content-div-NCwoyGmj874S2tcQhNTbKb span {
#             width: 100%;
#             height: 100%;
#             position: absolute;
#             top: 0;
#             left: 0;
#         }
#
#         div.ipyplot-content-div-NCwoyGmj874S2tcQhNTbKb img {
#             width: 700px;
#         }
#
#         div.ipyplot-content-div-NCwoyGmj874S2tcQhNTbKb span.ipyplot-img-close:hover {
#             cursor: zoom-out;
#         }
#         div.ipyplot-content-div-NCwoyGmj874S2tcQhNTbKb span.ipyplot-img-expand:hover {
#             cursor: zoom-in;
#         }
#
#         div[id^=ipyplot-content-div-NCwoyGmj874S2tcQhNTbKb]:target {
#             transform: scale(2.5);
#             transform-origin: left top;
#             z-index: 5000;
#             top: 0;
#             left: 0;
#             position: absolute;
#         }
#
#         div[id^=ipyplot-content-div-NCwoyGmj874S2tcQhNTbKb]:target span.ipyplot-img-close {
#             display: block;
#         }
#
#         div[id^=ipyplot-content-div-NCwoyGmj874S2tcQhNTbKb]:target span.ipyplot-img-expand {
#             display: none;
#         }
#         </style>
#     <div id="ipyplot-imgs-container-div-NCwoyGmj874S2tcQhNTbKb">
#     <div class="ipyplot-placeholder-div-NCwoyGmj874S2tcQhNTbKb">
#         <div id="ipyplot-content-div-NCwoyGmj874S2tcQhNTbKb-mKoHL7RcGC2py9oHHjRAx2" class="ipyplot-content-div-NCwoyGmj874S2tcQhNTbKb">
#             <h4 style="font-size: 12px; word-wrap: break-word;">0</h4>
#             <img src="data:image/png;base64,..."/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-NCwoyGmj874S2tcQhNTbKb-mKoHL7RcGC2py9oHHjRAx2">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#     </div>
#         </textarea>
#     </div>
#         <style>
#         #ipyplot-imgs-container-div-NCwoyGmj874S2tcQhNTbKb {
#             width: 100%;
#             height: 100%;
#             margin: 0%;
#             overflow: auto;
#             position: relative;
#             overflow-y: scroll;
#         }
#
#         div.ipyplot-placeholder-div-NCwoyGmj874S2tcQhNTbKb {
#             width: 700px;
#             display: inline-block;
#             margin: 3px;
#             position: relative;
#         }
#
#         div.ipyplot-content-div-NCwoyGmj874S2tcQhNTbKb {
#             width: 700px;
#             background: white;
#             display: inline-block;
#             vertical-align: top;
#             text-align: center;
#             position: relative;
#             border: 2px solid #ddd;
#             top: 0;
#             left: 0;
#         }
#
#         div.ipyplot-content-div-NCwoyGmj874S2tcQhNTbKb span.ipyplot-img-close {
#             display: none;
#         }
#
#         div.ipyplot-content-div-NCwoyGmj874S2tcQhNTbKb span {
#             width: 100%;
#             height: 100%;
#             position: absolute;
#             top: 0;
#             left: 0;
#         }
#
#         div.ipyplot-content-div-NCwoyGmj874S2tcQhNTbKb img {
#             width: 700px;
#         }
#
#         div.ipyplot-content-div-NCwoyGmj874S2tcQhNTbKb span.ipyplot-img-close:hover {
#             cursor: zoom-out;
#         }
#         div.ipyplot-content-div-NCwoyGmj874S2tcQhNTbKb span.ipyplot-img-expand:hover {
#             cursor: zoom-in;
#         }
#
#         div[id^=ipyplot-content-div-NCwoyGmj874S2tcQhNTbKb]:target {
#             transform: scale(2.5);
#             transform-origin: left top;
#             z-index: 5000;
#             top: 0;
#             left: 0;
#             position: absolute;
#         }
#
#         div[id^=ipyplot-content-div-NCwoyGmj874S2tcQhNTbKb]:target span.ipyplot-img-close {
#             display: block;
#         }
#
#         div[id^=ipyplot-content-div-NCwoyGmj874S2tcQhNTbKb]:target span.ipyplot-img-expand {
#             display: none;
#         }
#         </style>
#     <div id="ipyplot-imgs-container-div-NCwoyGmj874S2tcQhNTbKb">
#     <div class="ipyplot-placeholder-div-NCwoyGmj874S2tcQhNTbKb">
#         <div id="ipyplot-content-div-NCwoyGmj874S2tcQhNTbKb-mKoHL7RcGC2py9oHHjRAx2" class="ipyplot-content-div-NCwoyGmj874S2tcQhNTbKb">
#             <h4 style="font-size: 12px; word-wrap: break-word;">0</h4>
#             <img src="data:image/png;base64,..."/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-NCwoyGmj874S2tcQhNTbKb-mKoHL7RcGC2py9oHHjRAx2">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#     </div>

# %%
# area_accepted_gt = outputs[0][1]['all_accepted_T_2d_closest_gt']
# all_factors_T_2d_closest_gt = outputs[0][1]['all_factors_T_2d_closest_gt']

# def get_threshold_for_max_area(area_accepted_gt,all_factors_T_2d_closest_gt,w=1296):
#     max_area = np.max(all_factors_T_2d_closest_gt[area_accepted_gt])
#     return max_area ** 0.5 / w

# threshold = get_threshold_for_max_area(area_accepted_gt,all_factors_T_2d_closest_gt)
# print(threshold)

# %%
threshold = 0.0

names_plots = ['T for selected S','T for closest S','S for selected T','S for closest T']


for stage in range(len(outputs)):

    print(global_config["hierachial_grid_search"]["stages"][stage])

    pose_information,factor_output,imgs,img_annotations,_ = outputs[stage]
    indices = [factor_output['selected_T_selected_S']['S_index'],factor_output['closest_T_closest_S']['S_index'],factor_output['selected_T_selected_S']['T_index'],factor_output['closest_T_closest_S']['T_index']]

    Ts = np.array(factor_output["T"])
    Ss = np.array(factor_output["S"])
    factor = np.array(factor_output["factors"]).reshape((Ts.shape[0],Ss.shape[0]))
    
    if global_config["hierachial_grid_search"]["stages"][stage]['which'] == 'T':
        j = 0
        factor_selected = factor[:,indices[j]]
        create_k3d_plot(Ts[factor_selected > threshold],factor_selected[factor_selected > threshold],np.array(pose_information['gt_T']),point_size=get_pointsize_from_Ts(Ts),highlight='max',relative_highlight_size=1)
    elif global_config["hierachial_grid_search"]["stages"][stage]['which'] == 'S':
        j = 2
        factor_selected = factor[indices[j],:]
        create_k3d_plot(Ss[factor_selected > threshold],factor_selected[factor_selected > threshold],np.array(pose_information['gt_S_normalised']),point_size=get_pointsize_from_Ts(Ss),highlight='max',relative_highlight_size=1)
    else:
        print('S')
        factor_selected = factor[indices[2],:]
        create_k3d_plot(Ss[factor_selected > threshold],factor_selected[factor_selected > threshold],np.array(pose_information['gt_S_normalised']),point_size=get_pointsize_from_Ts(Ss),highlight='max',relative_highlight_size=1)
        print('T')
        factor_selected = factor[:,indices[0]]
        create_k3d_plot(Ts[factor_selected > threshold],factor_selected[factor_selected > threshold],np.array(pose_information['gt_T']),point_size=get_pointsize_from_Ts(Ts),highlight='max',relative_highlight_size=1)
# Out:
# {'which': 'T', 'info_T': {'center': 'gt', 'range': 0.5, 'range_type': 'absolute', 'steps_per_dim': 10}}
# Output()

# %%
# for BBOX
for i in range(len(configs)):
    pose_information,factor_output,imgs,img_annotations,_ = outputs[i]
    Ts = np.array(factor_output["T"])
    if i == 0:
        factor = np.array(factor_output["box_iou"])
    if i == 1:
        factor = np.array(factor_output["area_accepted_all_Ts"])
    create_k3d_plot(Ts,factor,np.array(pose_information['gt_T']),point_size=get_pointsize_from_Ts(Ts),highlight='max',relative_highlight_size=1)
    # print(factor)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-21-22f557cd52bd> in <module>
#       4     Ts = np.array(factor_output["T"])
#       5     if i == 0:
# ----> 6         factor = np.array(factor_output["box_iou"])
#       7     if i == 1:
#       8         factor = np.array(factor_output["area_accepted_all_Ts"])
#
# KeyError: 'box_iou'

# %%
for i in [1]:
    pose_information,factor_output,imgs,img_annotations,_ = outputs[i]
    # have zeros if not 
    Ts = np.array(factor_output["T"])
    area_accpeted_all_Ts = np.array(factor_output["area_accepted_all_Ts"])
    # print(Ts)
    create_k3d_plot(Ts,area_accpeted_all_Ts,np.array(pose_information['gt_T']),point_size=get_pointsize_from_Ts(Ts),highlight='min',relative_highlight_size=1)
    print(factor_output["area_accepted_all_Ts"])
# Out:
# /home/mifs/fml35/environments/torch1.9/lib/python3.7/site-packages/traittypes/traittypes.py:101: UserWarning: Given trait value dtype "int64" does not match required type "uint32". A coerced copy has been created.
#   np.dtype(self.dtype).name))
# /home/mifs/fml35/environments/torch1.9/lib/python3.7/site-packages/traittypes/traittypes.py:101: UserWarning: Given trait value dtype "float64" does not match required type "float32". A coerced copy has been created.
#   np.dtype(self.dtype).name))
# Output()
# [43377.625 43377.625 43377.625 ... 43377.625 43377.625 43377.625]

# %%
# in image x point left, y points up and z points into image
for i in [1]:
    pose_information,factor_output,imgs,img_annotations,_ = outputs[i]
    Ts = np.array(factor_output["T"])
    factors = np.array(factor_output["n_accepted_all_Ts"])
    create_k3d_plot(np.array(Ts),np.array(factors),np.array(pose_information['gt_T']),point_size=get_pointsize_from_Ts(Ts),relative_highlight_size=1.)
# Out:
# /home/mifs/fml35/environments/torch1.9/lib/python3.7/site-packages/traittypes/traittypes.py:101: UserWarning: Given trait value dtype "int64" does not match required type "uint32". A coerced copy has been created.
#   np.dtype(self.dtype).name))
# /home/mifs/fml35/environments/torch1.9/lib/python3.7/site-packages/traittypes/traittypes.py:101: UserWarning: Given trait value dtype "float64" does not match required type "float32". A coerced copy has been created.
#   np.dtype(self.dtype).name))
# Output()

# %%
for i in range(len(configs)):
    pose_information,factor_output,imgs,img_annotations,_ = outputs[i]
    Ts = np.array(factor_output["T"])
    factors = np.array(factor_output["n_accepted_all_Ts"])

    mask_factors = np.array(factors) > 11.5
    factors = 1- mask_factors * 1
    create_k3d_plot(np.array(Ts),np.array(factors),np.array(pose_information['gt_T']),point_size=get_pointsize_from_Ts(Ts),relative_highlight_size=1)
# Out:
# Output()

# %%
all_2d_to_all_3d = outputs[0][1]["all_factors_T_2d_3d_selected_T"]
print(all_2d_to_all_3d.shape)
# Out:
# (31, 65)
