# %%
depth_1 = cv2.imread('/scratch/fml35/datasets/own_datasets/leveraging_geometry_for_shape_estimation/scannet/data_03/val/depth_gb_640_480/scene0011_00-000000.png',cv2.IMREAD_UNCHANGED)
depth_2 = cv2.imread('/scratch/fml35/datasets/own_datasets/leveraging_geometry_for_shape_estimation/scannet/data_03/val/depth_640_480/scene0011_00-000000.png',cv2.IMREAD_UNCHANGED)
print(depth_1.shape)
print(np.max(depth_1))
print(np.min(depth_1))
print(depth_2.shape)
print(np.max(depth_2))
print(np.min(depth_2))
print(depth_2.dtype)

depth_1 = depth_1.astype(float)
depth_2 = depth_2.astype(float)

plt.imshow(depth_1)
plt.show()
plt.imshow(depth_2)
plt.show()
# Out:
# (480, 640)
# 3525
# 878
# (480, 640)
# 3897
# 0
# uint16

# %%
import cv2
import numpy as np
from matplotlib import pyplot as plt



depth = cv2.imread('/scratch/fml35/datasets/own_datasets/leveraging_geometry_for_shape_estimation/scannet/data_03/train/reprojected_gt_depth/scene0000_00-000100_01.png',cv2.IMREAD_UNCHANGED)
depth = depth.astype(float)

# print(depth[310:350,340:342])
depth[310:350,340:342] = depth[310:350,340:342]* 0 +  65535
plt.imshow(depth)

# depth[depth > 60000] = depth[depth > 60000] * 0 - 1
# depth = depth / 1000

# depth_gt = cv2.imread(,cv2.IMREAD_UNCHANGED)
# depth_gt = depth_gt.astype(float) / 1000

# depth_diff = np.abs(depth - depth_gt)
# depth_diff[depth < 0] = 10
# Out:
# [[65535. 65535.]
#  [65535. 65535.]
#  [65535. 65535.]
#  [65535. 65535.]
#  [65535. 65535.]
#  [65535. 65535.]
#  [65535. 65535.]
#  [65535. 65535.]
#  [65535. 65535.]
#  [65535. 65535.]
#  [ 2053.  2620.]
#  [ 2609.  2608.]
#  [ 2597.  2597.]
#  [ 2585.  2585.]
#  [ 2573.  2573.]
#  [ 2562.  2561.]
#  [ 2551.  2550.]
#  [ 2539.  2539.]
#  [ 2528.  2528.]
#  [ 2517.  2517.]
#  [ 2506.  2505.]
#  [ 2494.  2494.]
#  [ 2483.  2483.]
#  [ 2472.  2472.]
#  [ 2462.  2462.]
#  [ 2451.  2451.]
#  [ 2441.  2441.]
#  [ 2431.  2430.]
#  [ 2420.  2420.]
#  [ 2410.  2410.]
#  [ 2400.  2400.]
#  [ 2390.  2390.]
#  [ 2380.  2380.]
#  [ 2370.  2370.]
#  [ 2361.  2360.]
#  [ 2351.  2350.]
#  [ 2341.  2340.]
#  [ 2331.  2330.]
#  [ 2321.  2321.]
#  [ 2312.  2311.]]

# %%
depth = cv2.imread('/scratch/fml35/datasets/own_datasets/leveraging_geometry_for_shape_estimation/scannet/data_03/train/depth_640_480/scene0000_00-000100.png',cv2.IMREAD_UNCHANGED)
depth = depth.astype(float)

print(depth[310:350,340:342])
# depth[230:250,390:392] = depth[230:250,390:392]* 0 +  65535
plt.imshow(depth)
# Out:
# [[2650. 2647.]
#  [2659. 2655.]
#  [2663. 2658.]
#  [2664. 2661.]
#  [2665. 2666.]
#  [2651. 2651.]
#  [2614. 2628.]
#  [2572. 2590.]
#  [2543. 2559.]
#  [2533. 2535.]
#  [2530. 2531.]
#  [2515. 2516.]
#  [2504. 2505.]
#  [2503. 2504.]
#  [2505. 2505.]
#  [2507. 2506.]
#  [2500. 2508.]
#  [2499. 2498.]
#  [2491. 2490.]
#  [2491. 2490.]
#  [2481. 2479.]
#  [2471. 2470.]
#  [2470. 2462.]
#  [2462. 2461.]
#  [2461. 2451.]
#  [2450. 2451.]
#  [2449. 2444.]
#  [2443. 2440.]
#  [2440. 2430.]
#  [2426. 2421.]
#  [2412. 2405.]
#  [2383. 2385.]
#  [2372. 2373.]
#  [2372. 2372.]
#  [2373. 2373.]
#  [2366. 2366.]
#  [2356. 2355.]
#  [2356. 2355.]
#  [2347. 2348.]
#  [2338. 2338.]]

# %%
depth = cv2.imread('/scratch/fml35/datasets/own_datasets/leveraging_geometry_for_shape_estimation/scannet/data_03/train/depth_480_360/scene0000_00-000100.png',cv2.IMREAD_UNCHANGED)
depth = depth.astype(float)

print(depth[243,260])
# depth[230:250,390:392] = depth[230:250,390:392]* 0 +  65535
plt.imshow(depth)
# Out:
# 2519.0
