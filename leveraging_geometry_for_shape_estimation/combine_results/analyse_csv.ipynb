# %%
import pandas as pd

df = pd.read_csv('/scratch/fml35/experiments/leveraging_geometry_for_shape/exp_036_s2_predicted_gt_retrieval_gt_T_factor_rotation_vp/global_stats/all_infos.csv')

# %%
angles_by_cat = {"bed": [],"bookcase": [],"chair": [],"desk": [],"misc": [],"sofa": [],"table": [],"tool": [],"wardrobe": []} 

for ind in df.index:
    if df[""]
    cat = df["gt_category"][ind]
    angle = df["total_angle_diff"][ind]
    angles_by_cat[cat].append(angle)

# %%
from matplotlib import pyplot as plt
import numpy as np
for cat in angles_by_cat:
    print(cat + ' mean ' + str(np.mean(angles_by_cat[cat])))
    print(cat + ' median ' + str(np.median(angles_by_cat[cat])))
    plt.hist(angles_by_cat[cat])
    plt.show()
# Out:
# bed mean 6.504192895978263
# bed median 3.582627254785276
# bookcase mean 19.870938674088734
# bookcase median 5.422857838217226
# chair mean 10.384536342227092
# chair median 6.357363962898733
# desk mean 5.677367305335862
# desk median 3.627443941952443
# misc mean 26.7495420457567
# misc median 25.514243980310713
# sofa mean 6.8578251693838626
# sofa median 4.465070658327378
# table mean 9.603920787620979
# table median 4.910268915865445
# tool mean 46.22493730731673
# tool median 31.695119672519894
# wardrobe mean 5.684811845517844
# wardrobe median 3.705517408623907
